# %%
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import requests
from io import BytesIO

# %%
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
number_classes =3
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, number_classes)
# Out:
# /Users/dhaneshkumarkapadia/Desktop/swinTransformer/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/dhaneshkumarkapadia/Desktop/swinTransformer/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])
img_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Huskiesatrest.jpg/1920px-Huskiesatrest.jpg'
response = requests.get(img_url)
#img = Image.open(BytesIO(response.content)).convert('RGB')
img = Image.open("pngtree-many-happy-dogs-in-the-grass-with-copyspace-png-image_10276283.png").convert('RGB')

img= transform(img)
img = img.unsqueeze(0)
#original_img = Image.open("dog.jpg").convert("RGB")
#draw_img = np.array(img)

# %%
model.eval()
with torch.no_grad():
    pred = model(draw_img)

boxes = pred[0]['boxes'].cpu().numpy()
scores = pred[0]['scores'].cpu().numpy()


for box, score in zip(boxes, scores):
    if score > 0.8:
        x1, y1, x2, y2 = box
        x1,y1,x2,y2 = int(x1), int(y1), int(x2), int(y2)
        img = np.array(img.permute(1,2,0))
        img = cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,0),2)
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 model.eval()
#       2 with torch.no_grad():
# ----> 3     pred = model(draw_img)
#       5 boxes = pred[0]['boxes'].cpu().numpy()
#       6 scores = pred[0]['scores'].cpu().numpy()
#
# File ~/Desktop/swinTransformer/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/swinTransformer/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
# ...
